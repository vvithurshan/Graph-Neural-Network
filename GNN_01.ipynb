# %% [markdown]
# <a href="https://colab.research.google.com/github/vvithurshan/Graph-Neural-Network/blob/main/GNN_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx

# %% [markdown]
# ## **Undirected graphs**

# %%
G = nx.Graph()
G.add_edges_from([('A', 'B'), ('A', 'C'), ('B', 'D'), ('B', 'E'), ('C', 'F'), ('C', 'G')])
nx.draw(G, with_labels = True)

# %% [markdown]
# ## **Directed Graphs**

# %%
DG = nx.DiGraph()
DG.add_edges_from([('A', 'B'), ('A', 'C'), ('B', 'D'), ('B', 'E'), ('C', 'F'), ('C', 'G')])
nx.draw(DG, with_labels=True)

# %% [markdown]
# ## **Weighted Graphs**

# %%
WG = nx.Graph()
WG.add_edges_from([('A', 'B', {'weight':10}), ('A', 'C', {'weight':10}), ('B', 'D', {'weight':20}), ('B', 'E', {'weight':30}), ('C', 'F', {'weight':25}), ('C', 'G', {'weight':40})])
pos = nx.spring_layout(WG, seed=0) # store the layout in a variable
nx.draw(WG, pos=pos, with_labels=True) # use the same layout for drawing the graph
labels = nx.get_edge_attributes(WG, "weight")
nx.draw_networkx_edge_labels(WG, pos=pos, edge_labels=labels) # use the same layout for drawing the edge labels
# Out:
# {('A', 'B'): Text(0.2817515293230095, -0.21749269755027106, '10'),
#  ('A', 'C'): Text(-0.2936533514080969, 0.22119059448006964, '10'),
#  ('B', 'D'): Text(0.7839976964229359, -0.4185613247826042, '20'),
#  ('B', 'E'): Text(0.5916972554096522, -0.612736822634355, '30'),
#  ('C', 'F'): Text(-0.7838473256782352, 0.4294878316116856, '25'),
#  ('C', 'G'): Text(-0.5970109469396613, 0.6037102874280673, '40')}

# %% [markdown]
# ## **Connected graphs**

# %%
G1 = nx.Graph()
G1.add_edges_from([(1, 2), (2, 3), (3, 1), (4, 5)])
print(f"Is graph 1 connected? {nx.is_connected(G1)}")
nx.draw(G1, with_labels=True)
G2 = nx.Graph()
# Out:
# Is graph 1 connected? False

# %%
G2.add_edges_from([(1, 2), (2, 3), (3, 1), (1, 4)])
print(f"Is graph 2 connected? {nx.is_connected(G2)}")
nx.draw(G2, with_labels=True)
# Out:
# Is graph 2 connected? True
